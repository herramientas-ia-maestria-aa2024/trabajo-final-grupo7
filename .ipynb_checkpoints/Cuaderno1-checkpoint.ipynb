# %%
import pandas as pd

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,1000):
    lista.append({'Nombre': fake.first_name(),'Apellido':fake.last_name(),'Dirección':fake.address(),'Correo electrónico':fake.email(),'Fecha de nacimiento':fake.date_of_birth()})

# %%
lista
# Out:
# [{'Nombre': 'Samuel',
#   'Apellido': 'Nicholson',
#   'Dirección': '266 Johnson Rest Apt. 564\nSouth Kristen, NM 83095',
#   'Correo electrónico': 'oharris@example.org',
#   'Fecha de nacimiento': datetime.date(1983, 1, 7)},
#  {'Nombre': 'Jessica',
#   'Apellido': 'Huffman',
#   'Dirección': 'PSC 9201, Box 4184\nAPO AA 81129',
#   'Correo electrónico': 'xhiggins@example.net',
#   'Fecha de nacimiento': datetime.date(2023, 10, 31)},
#  {'Nombre': 'Beverly',
#   'Apellido': 'Johnson',
#   'Dirección': '7732 Roberts Shores Suite 769\nLoganborough, MS 37017',
#   'Correo electrónico': 'jcurry@example.com',
#   'Fecha de nacimiento': datetime.date(1935, 10, 31)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Watson',
#   'Dirección': '054 Rodriguez Points Apt. 308\nColechester, SC 31594',
#   'Correo electrónico': 'boydmegan@example.org',
#   'Fecha de nacimiento': datetime.date(1931, 9, 8)},
#  {'Nombre': 'Linda',
#   'Apellido': 'Tucker',
#   'Dirección': '964 Lucas Key Suite 367\nSanchezville, VA 38199',
#   'Correo electrónico': 'kaitlynphillips@example.net',
#   'Fecha de nacimiento': datetime.date(1929, 10, 14)},
#  {'Nombre': 'Amy',
#   'Apellido': 'Fisher',
#   'Dirección': '0380 Matthew Cliff\nJonesside, MP 35119',
#   'Correo electrónico': 'nathanfisher@example.com',
#   'Fecha de nacimiento': datetime.date(1956, 4, 16)},
#  {'Nombre': 'Danielle',
#   'Apellido': 'Brown',
#   'Dirección': 'PSC 1724, Box 9622\nAPO AA 80364',
#   'Correo electrónico': 'xdalton@example.com',
#   'Fecha de nacimiento': datetime.date(2008, 5, 30)},
#  {'Nombre': 'Anna',
#   'Apellido': 'Phillips',
#   'Dirección': 'USNV Ritter\nFPO AA 64975',
#   'Correo electrónico': 'brian77@example.org',
#   'Fecha de nacimiento': datetime.date(1984, 11, 1)},
#  {'Nombre': 'Loretta',
#   'Apellido': 'Huang',
#   'Dirección': '8441 Ann Circles\nTownsendmouth, DE 43147',
#   'Correo electrónico': 'john94@example.com',
#   'Fecha de nacimiento': datetime.date(1971, 11, 15)},
#  {'Nombre': 'Alexander',
#   'Apellido': 'Jones',
#   'Dirección': '362 Kayla Mountains\nJacksonmouth, GU 16037',
#   'Correo electrónico': 'turnersara@example.com',
#   'Fecha de nacimiento': datetime.date(1920, 2, 9)},
#  {'Nombre': 'Gabriel',
#   'Apellido': 'Kelly',
#   'Dirección': '508 Braun Branch\nEthanstad, NE 26740',
#   'Correo electrónico': 'jennifer74@example.net',
#   'Fecha de nacimiento': datetime.date(1952, 8, 28)},
#  {'Nombre': 'Erica',
#   'Apellido': 'Gomez',
#   'Dirección': '207 Jessica Tunnel\nSherylfort, HI 10418',
#   'Correo electrónico': 'traceycastillo@example.org',
#   'Fecha de nacimiento': datetime.date(1963, 7, 29)},
#  {'Nombre': 'Luis',
#   'Apellido': 'Pham',
#   'Dirección': '9869 James Roads\nJasonbury, DE 96177',
#   'Correo electrónico': 'kaylawilliams@example.net',
#   'Fecha de nacimiento': datetime.date(1966, 5, 10)},
#  {'Nombre': 'Edward',
#   'Apellido': 'Hughes',
#   'Dirección': '80706 Vargas Ports\nMillsside, AR 51441',
#   'Correo electrónico': 'garzasamuel@example.org',
#   'Fecha de nacimiento': datetime.date(1958, 7, 4)},
#  {'Nombre': 'Alex',
#   'Apellido': 'Hernandez',
#   'Dirección': '2996 Timothy Crest Apt. 341\nMariaton, NV 69502',
#   'Correo electrónico': 'wmitchell@example.net',
#   'Fecha de nacimiento': datetime.date(1969, 10, 15)},
#  {'Nombre': 'Tanner',
#   'Apellido': 'Ramirez',
#   'Dirección': '3137 Pratt Street\nEdwinstad, KS 25289',
#   'Correo electrónico': 'robert26@example.org',
#   'Fecha de nacimiento': datetime.date(2016, 3, 25)},
#  {'Nombre': 'Brad',
#   'Apellido': 'Salas',
#   'Dirección': '157 Jacqueline Passage Suite 270\nSouth Angela, DC 41495',
#   'Correo electrónico': 'vholland@example.net',
#   'Fecha de nacimiento': datetime.date(1961, 6, 26)},
#  {'Nombre': 'Karen',
#   'Apellido': 'Bush',
#   'Dirección': '12855 Antonio Pine\nWest Brian, IA 79452',
#   'Correo electrónico': 'lwright@example.net',
#   'Fecha de nacimiento': datetime.date(2018, 4, 16)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Pacheco',
#   'Dirección': '549 Middleton Underpass\nPort Beth, MS 33565',
#   'Correo electrónico': 'normahughes@example.com',
#   'Fecha de nacimiento': datetime.date(1918, 4, 15)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Shields',
#   'Dirección': '965 Esparza Field\nLake Leslieton, AS 32044',
#   'Correo electrónico': 'swilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1951, 4, 2)},
#  {'Nombre': 'Teresa',
#   'Apellido': 'Bowen',
#   'Dirección': '43037 Stacy Centers Apt. 941\nJohnnytown, SD 59546',
#   'Correo electrónico': 'banderson@example.com',
#   'Fecha de nacimiento': datetime.date(1984, 8, 15)},
#  {'Nombre': 'Elizabeth',
#   'Apellido': 'Morrison',
#   'Dirección': 'Unit 2634 Box 8531\nDPO AA 07361',
#   'Correo electrónico': 'araymond@example.com',
#   'Fecha de nacimiento': datetime.date(1956, 6, 10)},
#  {'Nombre': 'Mike',
#   'Apellido': 'Porter',
#   'Dirección': '462 Harper Route\nPenaport, MN 77021',
#   'Correo electrónico': 'jonescourtney@example.net',
#   'Fecha de nacimiento': datetime.date(2010, 1, 26)},
#  {'Nombre': 'Frank',
#   'Apellido': 'Lopez',
#   'Dirección': 'Unit 8012 Box 1171\nDPO AE 89620',
#   'Correo electrónico': 'rickyrich@example.com',
#   'Fecha de nacimiento': datetime.date(1937, 4, 2)},
#  {'Nombre': 'David',
#   'Apellido': 'Jones',
#   'Dirección': '345 Jose Cove\nWilsonshire, NC 52232',
#   'Correo electrónico': 'nedwards@example.com',
#   'Fecha de nacimiento': datetime.date(1981, 3, 4)},
#  {'Nombre': 'Jacob',
#   'Apellido': 'Lester',
#   'Dirección': '54538 Martha Passage\nBrownshire, ID 24754',
#   'Correo electrónico': 'robin00@example.com',
#   'Fecha de nacimiento': datetime.date(1945, 1, 31)},
#  {'Nombre': 'Adam',
#   'Apellido': 'Gomez',
#   'Dirección': '028 Wade Courts\nPort Kelseymouth, CA 32687',
#   'Correo electrónico': 'nunezashley@example.com',
#   'Fecha de nacimiento': datetime.date(1961, 4, 7)},
#  {'Nombre': 'Gregory',
#   'Apellido': 'Dixon',
#   'Dirección': '965 Jennifer Walks Apt. 379\nJenniferhaven, WV 93233',
#   'Correo electrónico': 'daniel97@example.net',
#   'Fecha de nacimiento': datetime.date(2009, 10, 4)},
#  {'Nombre': 'Danielle',
#   'Apellido': 'Hall',
#   'Dirección': '773 Acosta Squares Apt. 678\nCynthiabury, NV 52031',
#   'Correo electrónico': 'oevans@example.com',
#   'Fecha de nacimiento': datetime.date(1926, 10, 16)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Hall',
#   'Dirección': '2807 Cervantes Circle Suite 327\nAmberland, MS 39633',
#   'Correo electrónico': 'samantha86@example.net',
#   'Fecha de nacimiento': datetime.date(2017, 2, 25)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Ramirez',
#   'Dirección': '371 Avery Skyway\nLeehaven, NC 62981',
#   'Correo electrónico': 'brennanchad@example.com',
#   'Fecha de nacimiento': datetime.date(1928, 2, 7)},
#  {'Nombre': 'Stephanie',
#   'Apellido': 'Park',
#   'Dirección': '37545 Erika Loop Apt. 307\nEast Nancy, MS 17643',
#   'Correo electrónico': 'wreid@example.org',
#   'Fecha de nacimiento': datetime.date(1980, 5, 29)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Harris',
#   'Dirección': '2293 James Prairie\nHallview, AL 44728',
#   'Correo electrónico': 'yjensen@example.org',
#   'Fecha de nacimiento': datetime.date(1909, 5, 4)},
#  {'Nombre': 'Randall',
#   'Apellido': 'Johnson',
#   'Dirección': '732 Richard Ways\nWest Pennyport, FM 49192',
#   'Correo electrónico': 'alicia12@example.com',
#   'Fecha de nacimiento': datetime.date(1914, 12, 27)},
#  {'Nombre': 'Anne',
#   'Apellido': 'Carter',
#   'Dirección': '635 Fletcher Dale Suite 991\nEast Madison, PA 07470',
#   'Correo electrónico': 'abigail29@example.com',
#   'Fecha de nacimiento': datetime.date(1969, 11, 27)},
#  {'Nombre': 'Adam',
#   'Apellido': 'Walters',
#   'Dirección': '5637 Timothy Mill Apt. 519\nJulieland, MN 07335',
#   'Correo electrónico': 'charles50@example.com',
#   'Fecha de nacimiento': datetime.date(1982, 11, 15)},
#  {'Nombre': 'William',
#   'Apellido': 'Davis',
#   'Dirección': 'Unit 4349 Box 6244\nDPO AA 29211',
#   'Correo electrónico': 'brittanyrogers@example.org',
#   'Fecha de nacimiento': datetime.date(1939, 12, 16)},
#  {'Nombre': 'Brandy',
#   'Apellido': 'Payne',
#   'Dirección': '368 Lauren Rue Suite 110\nEast Anthony, NY 95839',
#   'Correo electrónico': 'hendersondavid@example.com',
#   'Fecha de nacimiento': datetime.date(1912, 12, 28)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Mclaughlin',
#   'Dirección': '4769 Sullivan Centers Apt. 633\nMariastad, FM 91215',
#   'Correo electrónico': 'amanda23@example.com',
#   'Fecha de nacimiento': datetime.date(1912, 7, 16)},
#  {'Nombre': 'Carmen',
#   'Apellido': 'Acosta',
#   'Dirección': '213 Alvarado Ridge Apt. 911\nMoorechester, NC 22801',
#   'Correo electrónico': 'douglashiggins@example.org',
#   'Fecha de nacimiento': datetime.date(1916, 9, 25)},
#  {'Nombre': 'Barbara',
#   'Apellido': 'Ortiz',
#   'Dirección': '5518 Denise Islands Apt. 695\nPort Frankmouth, WV 83152',
#   'Correo electrónico': 'twatson@example.org',
#   'Fecha de nacimiento': datetime.date(1997, 5, 21)},
#  {'Nombre': 'Gary',
#   'Apellido': 'Knight',
#   'Dirección': '1730 David Plains\nSouth Laurachester, ND 40202',
#   'Correo electrónico': 'pmcguire@example.com',
#   'Fecha de nacimiento': datetime.date(1967, 4, 30)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Vasquez',
#   'Dirección': '466 Adams Club\nMurphyhaven, NJ 06625',
#   'Correo electrónico': 'mariahicks@example.org',
#   'Fecha de nacimiento': datetime.date(1958, 2, 21)},
#  {'Nombre': 'Ashley',
#   'Apellido': 'Gillespie',
#   'Dirección': '826 Smith Road\nWest Beverlyville, PA 05733',
#   'Correo electrónico': 'phillipspatricia@example.org',
#   'Fecha de nacimiento': datetime.date(1970, 6, 18)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'James',
#   'Dirección': 'Unit 0322 Box 6791\nDPO AE 90079',
#   'Correo electrónico': 'oshaffer@example.net',
#   'Fecha de nacimiento': datetime.date(1968, 2, 4)},
#  {'Nombre': 'Deborah',
#   'Apellido': 'Haas',
#   'Dirección': '54845 William Trail Suite 799\nWest Rebecca, MN 38681',
#   'Correo electrónico': 'danielle10@example.com',
#   'Fecha de nacimiento': datetime.date(1962, 10, 5)},
#  {'Nombre': 'Eddie',
#   'Apellido': 'Huerta',
#   'Dirección': '671 Mclaughlin Fields\nSouth Stephanieberg, IN 77932',
#   'Correo electrónico': 'nathanballard@example.com',
#   'Fecha de nacimiento': datetime.date(1935, 9, 12)},
#  {'Nombre': 'Kyle',
#   'Apellido': 'Hill',
#   'Dirección': '218 Fletcher Plains Apt. 617\nMartinfort, VI 87425',
#   'Correo electrónico': 'weisschristina@example.net',
#   'Fecha de nacimiento': datetime.date(1919, 10, 27)},
#  {'Nombre': 'James',
#   'Apellido': 'Ball',
#   'Dirección': '55806 Burns Ferry\nChristopherville, IN 49380',
#   'Correo electrónico': 'hannah40@example.net',
#   'Fecha de nacimiento': datetime.date(1937, 8, 21)},
#  {'Nombre': 'Jenny',
#   'Apellido': 'Allen',
#   'Dirección': '04320 Wright Roads Suite 196\nAngelaborough, NJ 27937',
#   'Correo electrónico': 'kimingram@example.org',
#   'Fecha de nacimiento': datetime.date(2003, 3, 31)},
#  {'Nombre': 'Tina',
#   'Apellido': 'Wagner',
#   'Dirección': '140 Gallegos Estate\nEast Katrinamouth, SD 81163',
#   'Correo electrónico': 'arthurphillips@example.org',
#   'Fecha de nacimiento': datetime.date(1960, 6, 25)},
#  {'Nombre': 'Kyle',
#   'Apellido': 'Ramirez',
#   'Dirección': '504 Lisa Brooks Apt. 616\nBryantburgh, GA 76556',
#   'Correo electrónico': 'foxheather@example.net',
#   'Fecha de nacimiento': datetime.date(1988, 2, 5)},
#  {'Nombre': 'David',
#   'Apellido': 'Perez',
#   'Dirección': 'Unit 7911 Box 7060\nDPO AA 98937',
#   'Correo electrónico': 'rowekim@example.org',
#   'Fecha de nacimiento': datetime.date(1993, 4, 30)},
#  {'Nombre': 'James',
#   'Apellido': 'Jimenez',
#   'Dirección': '29316 Perkins Parkway Apt. 978\nLake Maryport, MP 83069',
#   'Correo electrónico': 'dpatterson@example.net',
#   'Fecha de nacimiento': datetime.date(2022, 5, 28)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Phelps',
#   'Dirección': '09516 Joseph Bypass\nMorenoport, KS 38440',
#   'Correo electrónico': 'brittney83@example.com',
#   'Fecha de nacimiento': datetime.date(1941, 5, 10)},
#  {'Nombre': 'Brandon',
#   'Apellido': 'Jones',
#   'Dirección': '4580 Greer Summit Suite 725\nGreenchester, NE 41180',
#   'Correo electrónico': 'alicia71@example.org',
#   'Fecha de nacimiento': datetime.date(2017, 8, 14)},
#  {'Nombre': 'Stephanie',
#   'Apellido': 'Underwood',
#   'Dirección': '87865 Peterson Village\nWest Saraland, MP 45435',
#   'Correo electrónico': 'meganwilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1957, 1, 9)},
#  {'Nombre': 'Eric',
#   'Apellido': 'Beck',
#   'Dirección': 'Unit 9981 Box 4929\nDPO AA 73725',
#   'Correo electrónico': 'pmatthews@example.com',
#   'Fecha de nacimiento': datetime.date(2023, 4, 11)},
#  {'Nombre': 'Amber',
#   'Apellido': 'Hanson',
#   'Dirección': '0614 Noah Path Suite 357\nRobinsonshire, VT 07753',
#   'Correo electrónico': 'stephanie85@example.com',
#   'Fecha de nacimiento': datetime.date(1938, 4, 6)},
#  {'Nombre': 'Mary',
#   'Apellido': 'Porter',
#   'Dirección': '215 Rita Center Suite 582\nJeffreyside, TN 23298',
#   'Correo electrónico': 'rogerswendy@example.com',
#   'Fecha de nacimiento': datetime.date(1991, 2, 15)},
#  {'Nombre': 'Raymond',
#   'Apellido': 'Huynh',
#   'Dirección': '43526 William Point\nLake Josephfurt, ND 75740',
#   'Correo electrónico': 'karen89@example.com',
#   'Fecha de nacimiento': datetime.date(1922, 3, 2)},
#  {'Nombre': 'Lucas',
#   'Apellido': 'Herrera',
#   'Dirección': '81490 Boone Tunnel\nNorth Emilyville, NC 66465',
#   'Correo electrónico': 'yboyle@example.net',
#   'Fecha de nacimiento': datetime.date(1920, 8, 29)},
#  {'Nombre': 'Katherine',
#   'Apellido': 'Smith',
#   'Dirección': 'USNV Bennett\nFPO AA 35821',
#   'Correo electrónico': 'kimberlyscott@example.org',
#   'Fecha de nacimiento': datetime.date(2017, 8, 5)},
#  {'Nombre': 'Lisa',
#   'Apellido': 'Johnson',
#   'Dirección': '6605 Jennifer Road\nJeffreyfurt, PW 32801',
#   'Correo electrónico': 'martinjessica@example.org',
#   'Fecha de nacimiento': datetime.date(2003, 7, 18)},
#  {'Nombre': 'Terri',
#   'Apellido': 'Weiss',
#   'Dirección': '5720 Jones Pine Apt. 005\nNew Andreport, MH 49332',
#   'Correo electrónico': 'jonesdiane@example.org',
#   'Fecha de nacimiento': datetime.date(1974, 9, 14)},
#  {'Nombre': 'Gina',
#   'Apellido': 'Sanders',
#   'Dirección': '053 Cole Parkways\nNorth Michele, VT 83832',
#   'Correo electrónico': 'rollinswhitney@example.com',
#   'Fecha de nacimiento': datetime.date(1982, 6, 30)},
#  {'Nombre': 'David',
#   'Apellido': 'Maynard',
#   'Dirección': '423 Ray Centers\nNashshire, NE 45757',
#   'Correo electrónico': 'elizabethrussell@example.net',
#   'Fecha de nacimiento': datetime.date(2018, 9, 27)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Smith',
#   'Dirección': '411 Wilson Stream Apt. 713\nDownsstad, MP 11392',
#   'Correo electrónico': 'nataliehall@example.org',
#   'Fecha de nacimiento': datetime.date(1951, 8, 4)},
#  {'Nombre': 'Victor',
#   'Apellido': 'Bartlett',
#   'Dirección': '2089 Jasmine Walk Apt. 499\nSharonburgh, NC 03831',
#   'Correo electrónico': 'ngray@example.org',
#   'Fecha de nacimiento': datetime.date(1953, 1, 27)},
#  {'Nombre': 'Eric',
#   'Apellido': 'Wilson',
#   'Dirección': '6791 Porter Views\nWest John, HI 58512',
#   'Correo electrónico': 'davisandrea@example.com',
#   'Fecha de nacimiento': datetime.date(1970, 4, 25)},
#  {'Nombre': 'Jared',
#   'Apellido': 'Hernandez',
#   'Dirección': '9692 Edwards Causeway Apt. 158\nNew Traceymouth, GU 76362',
#   'Correo electrónico': 'mlowe@example.net',
#   'Fecha de nacimiento': datetime.date(1971, 10, 25)},
#  {'Nombre': 'Craig',
#   'Apellido': 'Martin',
#   'Dirección': 'Unit 7686 Box 0315\nDPO AA 09820',
#   'Correo electrónico': 'jessicataylor@example.net',
#   'Fecha de nacimiento': datetime.date(1963, 10, 8)},
#  {'Nombre': 'Shane',
#   'Apellido': 'Cooper',
#   'Dirección': '2019 Michaela Terrace\nAmyberg, MD 74259',
#   'Correo electrónico': 'rebecca70@example.org',
#   'Fecha de nacimiento': datetime.date(1961, 3, 4)},
#  {'Nombre': 'Jay',
#   'Apellido': 'Graham',
#   'Dirección': '1872 Michelle Views\nPort Margaret, MD 96817',
#   'Correo electrónico': 'stephanie60@example.net',
#   'Fecha de nacimiento': datetime.date(1926, 12, 16)},
#  {'Nombre': 'Samuel',
#   'Apellido': 'Obrien',
#   'Dirección': '70593 Amy Crossroad Apt. 989\nByrdbury, NM 82715',
#   'Correo electrónico': 'kayleehebert@example.org',
#   'Fecha de nacimiento': datetime.date(1922, 6, 2)},
#  {'Nombre': 'Richard',
#   'Apellido': 'Garrett',
#   'Dirección': '821 Connie Mount\nToniville, ME 52891',
#   'Correo electrónico': 'vevans@example.com',
#   'Fecha de nacimiento': datetime.date(1912, 9, 8)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Harris',
#   'Dirección': '78197 Dunn Summit Apt. 791\nNorth Trevor, SC 33544',
#   'Correo electrónico': 'travismorgan@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 8, 20)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Johnson',
#   'Dirección': '702 Brian Cliff Suite 795\nCampbellside, IA 31556',
#   'Correo electrónico': 'lknight@example.com',
#   'Fecha de nacimiento': datetime.date(1953, 7, 13)},
#  {'Nombre': 'Isabel',
#   'Apellido': 'Perry',
#   'Dirección': '242 Noah Tunnel Suite 147\nSouth Davidmouth, CT 91027',
#   'Correo electrónico': 'brandon37@example.com',
#   'Fecha de nacimiento': datetime.date(1941, 5, 26)},
#  {'Nombre': 'Erik',
#   'Apellido': 'Wise',
#   'Dirección': '15664 Gray Light\nNew Ronaldshire, DE 87518',
#   'Correo electrónico': 'belindamendoza@example.org',
#   'Fecha de nacimiento': datetime.date(1913, 9, 30)},
#  {'Nombre': 'Lindsey',
#   'Apellido': 'Black',
#   'Dirección': 'Unit 0932 Box 1877\nDPO AP 40221',
#   'Correo electrónico': 'daniel25@example.com',
#   'Fecha de nacimiento': datetime.date(1922, 4, 5)},
#  {'Nombre': 'Sandra',
#   'Apellido': 'Greene',
#   'Dirección': '577 Johnson Circle Suite 085\nAmyburgh, AL 54724',
#   'Correo electrónico': 'brandon03@example.org',
#   'Fecha de nacimiento': datetime.date(1913, 10, 17)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'King',
#   'Dirección': 'Unit 0104 Box 7904\nDPO AA 08976',
#   'Correo electrónico': 'brookslaura@example.net',
#   'Fecha de nacimiento': datetime.date(1966, 5, 25)},
#  {'Nombre': 'Angela',
#   'Apellido': 'Martinez',
#   'Dirección': '5013 Randy Spur Suite 650\nDixonland, AK 35880',
#   'Correo electrónico': 'jennifer62@example.net',
#   'Fecha de nacimiento': datetime.date(1970, 11, 21)},
#  {'Nombre': 'Craig',
#   'Apellido': 'Cain',
#   'Dirección': '7778 David Ports Suite 837\nEast Jenna, FL 43183',
#   'Correo electrónico': 'davisangela@example.com',
#   'Fecha de nacimiento': datetime.date(1986, 7, 9)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Parker',
#   'Dirección': '24145 Brown Camp\nNew Brandon, MO 70194',
#   'Correo electrónico': 'james46@example.net',
#   'Fecha de nacimiento': datetime.date(2023, 7, 17)},
#  {'Nombre': 'Bethany',
#   'Apellido': 'Maxwell',
#   'Dirección': '2034 Daniel Cove\nNorth Matthew, FM 78771',
#   'Correo electrónico': 'fryechristy@example.com',
#   'Fecha de nacimiento': datetime.date(2010, 5, 3)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Williams',
#   'Dirección': 'Unit 1502 Box 7532\nDPO AA 63093',
#   'Correo electrónico': 'lesliehoffman@example.com',
#   'Fecha de nacimiento': datetime.date(1958, 4, 3)},
#  {'Nombre': 'Julia',
#   'Apellido': 'Molina',
#   'Dirección': 'PSC 9955, Box 6967\nAPO AP 36996',
#   'Correo electrónico': 'lbooker@example.net',
#   'Fecha de nacimiento': datetime.date(1932, 10, 31)},
#  {'Nombre': 'Leslie',
#   'Apellido': 'Alexander',
#   'Dirección': '9455 Danielle Squares Suite 300\nSouth Jasonmouth, SD 82250',
#   'Correo electrónico': 'christy83@example.net',
#   'Fecha de nacimiento': datetime.date(2010, 5, 24)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Nelson',
#   'Dirección': '20313 Michael Stravenue Apt. 069\nNew Austinstad, NY 71282',
#   'Correo electrónico': 'robinsoncorey@example.com',
#   'Fecha de nacimiento': datetime.date(1910, 7, 27)},
#  {'Nombre': 'Peggy',
#   'Apellido': 'Carter',
#   'Dirección': '44253 Simon Ridge\nEast Brandon, NY 06095',
#   'Correo electrónico': 'phillipstommy@example.com',
#   'Fecha de nacimiento': datetime.date(1998, 3, 11)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Smith',
#   'Dirección': '43274 Angela Manors Apt. 696\nDawnchester, NJ 90669',
#   'Correo electrónico': 'brian41@example.net',
#   'Fecha de nacimiento': datetime.date(1939, 10, 31)},
#  {'Nombre': 'Katelyn',
#   'Apellido': 'Ellis',
#   'Dirección': '153 Heather Forest\nNorrismouth, MH 79044',
#   'Correo electrónico': 'mary17@example.net',
#   'Fecha de nacimiento': datetime.date(1977, 12, 6)},
#  {'Nombre': 'William',
#   'Apellido': 'Young',
#   'Dirección': '1888 Vincent Mission\nLake Christian, OH 13623',
#   'Correo electrónico': 'denniskatie@example.com',
#   'Fecha de nacimiento': datetime.date(1967, 5, 9)},
#  {'Nombre': 'Shelia',
#   'Apellido': 'Wallace',
#   'Dirección': '6724 Nancy Haven Apt. 533\nWest John, MT 71408',
#   'Correo electrónico': 'alicia42@example.net',
#   'Fecha de nacimiento': datetime.date(1986, 5, 21)},
#  {'Nombre': 'Gail',
#   'Apellido': 'Hall',
#   'Dirección': '1632 Nichols Key Apt. 928\nWest Elizabethburgh, VA 77160',
#   'Correo electrónico': 'ramirezcollin@example.net',
#   'Fecha de nacimiento': datetime.date(2022, 5, 6)},
#  {'Nombre': 'Angela',
#   'Apellido': 'Lee',
#   'Dirección': '18591 Brown Expressway\nSamuelchester, AL 13472',
#   'Correo electrónico': 'collinskyle@example.net',
#   'Fecha de nacimiento': datetime.date(1914, 10, 6)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Robertson',
#   'Dirección': '4847 Heidi Burg Suite 024\nLake Larry, CO 36113',
#   'Correo electrónico': 'jenniferallison@example.com',
#   'Fecha de nacimiento': datetime.date(1957, 5, 31)},
#  {'Nombre': 'Gabriela',
#   'Apellido': 'Henry',
#   'Dirección': '110 Ponce Trail\nDukestad, AZ 39276',
#   'Correo electrónico': 'stevennorris@example.net',
#   'Fecha de nacimiento': datetime.date(1933, 1, 4)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Allen',
#   'Dirección': 'PSC 2113, Box 5718\nAPO AA 15490',
#   'Correo electrónico': 'josewalsh@example.org',
#   'Fecha de nacimiento': datetime.date(1993, 11, 30)},
#  {'Nombre': 'Shannon',
#   'Apellido': 'Cummings',
#   'Dirección': '4538 Brown Valley\nNew Joseph, AK 34294',
#   'Correo electrónico': 'qfrancis@example.net',
#   'Fecha de nacimiento': datetime.date(1935, 11, 17)},
#  {'Nombre': 'Kelly',
#   'Apellido': 'Smith',
#   'Dirección': '4562 Chloe Mills Apt. 488\nMarkshire, TX 54666',
#   'Correo electrónico': 'ronniegrant@example.net',
#   'Fecha de nacimiento': datetime.date(2005, 5, 11)},
#  {'Nombre': 'Heather',
#   'Apellido': 'Smith',
#   'Dirección': '699 Allen Rue\nKathyside, MH 78711',
#   'Correo electrónico': 'richardwilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1951, 1, 15)},
#  {'Nombre': 'James',
#   'Apellido': 'Evans',
#   'Dirección': '42622 Jones Squares Apt. 778\nWrightport, PA 08459',
#   'Correo electrónico': 'ashley86@example.net',
#   'Fecha de nacimiento': datetime.date(1954, 3, 1)},
#  {'Nombre': 'Kiara',
#   'Apellido': 'Reeves',
#   'Dirección': '558 Hudson Course Suite 408\nSouth Laura, NV 42834',
#   'Correo electrónico': 'thomas69@example.org',
#   'Fecha de nacimiento': datetime.date(2007, 6, 4)},
#  {'Nombre': 'Benjamin',
#   'Apellido': 'Garcia',
#   'Dirección': '498 Samantha Landing Suite 543\nSouth Brian, WY 71393',
#   'Correo electrónico': 'usantos@example.com',
#   'Fecha de nacimiento': datetime.date(1932, 1, 25)},
#  {'Nombre': 'Dennis',
#   'Apellido': 'Aguirre',
#   'Dirección': '499 Jessica Track\nWest Monica, PW 27637',
#   'Correo electrónico': 'susanhicks@example.net',
#   'Fecha de nacimiento': datetime.date(1924, 7, 12)},
#  {'Nombre': 'Kathryn',
#   'Apellido': 'Fields',
#   'Dirección': '35390 Robert Alley\nWest Kennethmouth, MO 25351',
#   'Correo electrónico': 'perezkrista@example.com',
#   'Fecha de nacimiento': datetime.date(1963, 10, 27)},
#  {'Nombre': 'Robin',
#   'Apellido': 'Smith',
#   'Dirección': '1723 Eric Estates\nHillmouth, GU 22080',
#   'Correo electrónico': 'carterkevin@example.net',
#   'Fecha de nacimiento': datetime.date(1976, 3, 26)},
#  {'Nombre': 'Amy',
#   'Apellido': 'Jennings',
#   'Dirección': '3957 Lisa Way\nNew Crystal, PR 10763',
#   'Correo electrónico': 'alan87@example.org',
#   'Fecha de nacimiento': datetime.date(1966, 8, 25)},
#  {'Nombre': 'Melinda',
#   'Apellido': 'Allen',
#   'Dirección': '802 Richards Extension Apt. 630\nNew Annaborough, MT 13236',
#   'Correo electrónico': 'jessicawright@example.com',
#   'Fecha de nacimiento': datetime.date(1975, 2, 22)},
#  {'Nombre': 'Andrea',
#   'Apellido': 'Koch',
#   'Dirección': '82876 Trevino Mill Suite 026\nWest Cynthia, PW 24432',
#   'Correo electrónico': 'steven22@example.net',
#   'Fecha de nacimiento': datetime.date(1947, 7, 17)},
#  {'Nombre': 'Jaime',
#   'Apellido': 'Torres',
#   'Dirección': '4675 Moore Dale Apt. 403\nHarrisonfort, NY 89105',
#   'Correo electrónico': 'thomas31@example.org',
#   'Fecha de nacimiento': datetime.date(1946, 10, 1)},
#  {'Nombre': 'Sandra',
#   'Apellido': 'Williams',
#   'Dirección': '453 Angela Creek Apt. 839\nLisaberg, PW 80292',
#   'Correo electrónico': 'mberry@example.com',
#   'Fecha de nacimiento': datetime.date(1937, 5, 30)},
#  {'Nombre': 'Kenneth',
#   'Apellido': 'Mendez',
#   'Dirección': '04546 Lisa Haven\nColemanborough, WI 58342',
#   'Correo electrónico': 'qrobinson@example.net',
#   'Fecha de nacimiento': datetime.date(1959, 2, 10)},
#  {'Nombre': 'Bonnie',
#   'Apellido': 'Price',
#   'Dirección': '507 Frank River Apt. 176\nNew Michelle, MI 81573',
#   'Correo electrónico': 'twilson@example.com',
#   'Fecha de nacimiento': datetime.date(2016, 12, 14)},
#  {'Nombre': 'Jaime',
#   'Apellido': 'Mcguire',
#   'Dirección': '44035 Ward Vista Suite 763\nNorth Rebeccastad, WA 22889',
#   'Correo electrónico': 'jordansusan@example.net',
#   'Fecha de nacimiento': datetime.date(1953, 12, 20)},
#  {'Nombre': 'Sherri',
#   'Apellido': 'Payne',
#   'Dirección': '2743 Taylor Fork Suite 178\nEast Howardberg, AZ 80481',
#   'Correo electrónico': 'jay09@example.com',
#   'Fecha de nacimiento': datetime.date(1931, 1, 2)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Camacho',
#   'Dirección': '52789 Fernando Camp Apt. 609\nLake Alyssa, IN 22911',
#   'Correo electrónico': 'martinezrebecca@example.net',
#   'Fecha de nacimiento': datetime.date(2012, 9, 10)},
#  {'Nombre': 'Douglas',
#   'Apellido': 'Johnson',
#   'Dirección': '286 Kathleen Stravenue Suite 579\nEast Matthew, NH 32226',
#   'Correo electrónico': 'xcarr@example.com',
#   'Fecha de nacimiento': datetime.date(1943, 2, 15)},
#  {'Nombre': 'Lisa',
#   'Apellido': 'Miller',
#   'Dirección': '37005 Thompson Common Suite 890\nSimsfurt, AZ 60338',
#   'Correo electrónico': 'smiller@example.net',
#   'Fecha de nacimiento': datetime.date(1964, 9, 15)},
#  {'Nombre': 'Justin',
#   'Apellido': 'Martinez',
#   'Dirección': '252 Paul Plains\nJacksonland, TX 51035',
#   'Correo electrónico': 'ronnie47@example.com',
#   'Fecha de nacimiento': datetime.date(2007, 11, 13)},
#  {'Nombre': 'Justin',
#   'Apellido': 'Merritt',
#   'Dirección': '1311 Roberts Ways\nChristinestad, NV 04029',
#   'Correo electrónico': 'dserrano@example.org',
#   'Fecha de nacimiento': datetime.date(1994, 3, 15)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Allen',
#   'Dirección': '7199 Carter Dale\nNew Rebeccamouth, RI 01910',
#   'Correo electrónico': 'joshuawright@example.net',
#   'Fecha de nacimiento': datetime.date(1959, 2, 6)},
#  {'Nombre': 'Juan',
#   'Apellido': 'Smith',
#   'Dirección': '3418 Miller Point Suite 979\nPort Aliciafurt, DC 34216',
#   'Correo electrónico': 'donaldmyers@example.net',
#   'Fecha de nacimiento': datetime.date(1971, 3, 22)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Frye',
#   'Dirección': 'USNS West\nFPO AA 66361',
#   'Correo electrónico': 'briansmith@example.com',
#   'Fecha de nacimiento': datetime.date(1927, 10, 13)},
#  {'Nombre': 'Samantha',
#   'Apellido': 'George',
#   'Dirección': '990 Michael Pike\nLake Tracyhaven, NH 28466',
#   'Correo electrónico': 'abrowning@example.com',
#   'Fecha de nacimiento': datetime.date(1974, 5, 11)},
#  {'Nombre': 'Scott',
#   'Apellido': 'Barnes',
#   'Dirección': '689 Ramos Haven\nJamiemouth, PW 36571',
#   'Correo electrónico': 'robertwhite@example.org',
#   'Fecha de nacimiento': datetime.date(1962, 7, 28)},
#  {'Nombre': 'Eric',
#   'Apellido': 'Rodriguez',
#   'Dirección': '411 Wright Manor Apt. 808\nElliottstad, MT 14250',
#   'Correo electrónico': 'kevin40@example.org',
#   'Fecha de nacimiento': datetime.date(1929, 3, 28)},
#  {'Nombre': 'Matthew',
#   'Apellido': 'Cox',
#   'Dirección': '590 Brenda Inlet\nLake Matthewbury, IN 75915',
#   'Correo electrónico': 'claire91@example.org',
#   'Fecha de nacimiento': datetime.date(1940, 9, 18)},
#  {'Nombre': 'Jeffrey',
#   'Apellido': 'Jimenez',
#   'Dirección': 'PSC 3314, Box 5438\nAPO AA 64558',
#   'Correo electrónico': 'ethomas@example.org',
#   'Fecha de nacimiento': datetime.date(1952, 5, 8)},
#  {'Nombre': 'Destiny',
#   'Apellido': 'Jones',
#   'Dirección': '227 Lopez Port Suite 312\nLake Marcia, MI 46717',
#   'Correo electrónico': 'laurafox@example.org',
#   'Fecha de nacimiento': datetime.date(2006, 8, 3)},
#  {'Nombre': 'Phillip',
#   'Apellido': 'Chase',
#   'Dirección': 'Unit 2437 Box 7922\nDPO AE 98539',
#   'Correo electrónico': 'andrewwalker@example.org',
#   'Fecha de nacimiento': datetime.date(1919, 3, 11)},
#  {'Nombre': 'Charles',
#   'Apellido': 'Miller',
#   'Dirección': 'Unit 2032 Box 4374\nDPO AE 26317',
#   'Correo electrónico': 'catherinebrown@example.org',
#   'Fecha de nacimiento': datetime.date(1955, 6, 27)},
#  {'Nombre': 'Jean',
#   'Apellido': 'Yoder',
#   'Dirección': '695 Cynthia Cove\nNew Joe, CA 11705',
#   'Correo electrónico': 'victor87@example.org',
#   'Fecha de nacimiento': datetime.date(1931, 7, 6)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Tran',
#   'Dirección': '3069 Kelly Lakes Apt. 325\nEast Jessica, NV 01709',
#   'Correo electrónico': 'pelliott@example.com',
#   'Fecha de nacimiento': datetime.date(2021, 1, 21)},
#  {'Nombre': 'Mason',
#   'Apellido': 'King',
#   'Dirección': '0261 Charles Cove Apt. 010\nNorth Lindseyland, NY 86563',
#   'Correo electrónico': 'bobby06@example.org',
#   'Fecha de nacimiento': datetime.date(1959, 4, 29)},
#  {'Nombre': 'Erica',
#   'Apellido': 'Yang',
#   'Dirección': '54620 Ronald Heights\nCharlesburgh, DE 94889',
#   'Correo electrónico': 'andrew47@example.net',
#   'Fecha de nacimiento': datetime.date(2012, 1, 1)},
#  {'Nombre': 'Devin',
#   'Apellido': 'Walker',
#   'Dirección': '408 William Union Apt. 849\nKaitlynport, AR 27316',
#   'Correo electrónico': 'danieljacobs@example.net',
#   'Fecha de nacimiento': datetime.date(1919, 9, 12)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Bruce',
#   'Dirección': '76870 Richard Forks Apt. 256\nBethbury, WV 44628',
#   'Correo electrónico': 'martineznathaniel@example.com',
#   'Fecha de nacimiento': datetime.date(1910, 5, 18)},
#  {'Nombre': 'James',
#   'Apellido': 'Rice',
#   'Dirección': '43701 Wilkinson Pike\nConwayfurt, TN 59657',
#   'Correo electrónico': 'kylie97@example.org',
#   'Fecha de nacimiento': datetime.date(2006, 7, 7)},
#  {'Nombre': 'Rebecca',
#   'Apellido': 'Delgado',
#   'Dirección': '4365 Moore Squares Suite 822\nSullivanmouth, NM 58285',
#   'Correo electrónico': 'robertquinn@example.com',
#   'Fecha de nacimiento': datetime.date(2020, 1, 16)},
#  {'Nombre': 'Rebekah',
#   'Apellido': 'Rollins',
#   'Dirección': '382 Thompson Ville Suite 652\nAaronchester, NC 44068',
#   'Correo electrónico': 'kstephens@example.net',
#   'Fecha de nacimiento': datetime.date(2006, 11, 17)},
#  {'Nombre': 'Heather',
#   'Apellido': 'Williams',
#   'Dirección': '0395 Karen Trafficway Suite 888\nNew Josephstad, WV 74469',
#   'Correo electrónico': 'benjamin01@example.org',
#   'Fecha de nacimiento': datetime.date(2023, 12, 26)},
#  {'Nombre': 'Brooke',
#   'Apellido': 'Cooper',
#   'Dirección': '5290 Diane Canyon Suite 436\nWeaverland, VI 30549',
#   'Correo electrónico': 'robert65@example.com',
#   'Fecha de nacimiento': datetime.date(1986, 8, 31)},
#  {'Nombre': 'Krystal',
#   'Apellido': 'Wolfe',
#   'Dirección': '946 Edwards Glens\nEdgarchester, MH 20654',
#   'Correo electrónico': 'swalter@example.net',
#   'Fecha de nacimiento': datetime.date(1967, 2, 1)},
#  {'Nombre': 'Michael',
#   'Apellido': 'King',
#   'Dirección': '4441 Amanda Junctions\nPort Samuel, MP 84916',
#   'Correo electrónico': 'davidmccarthy@example.com',
#   'Fecha de nacimiento': datetime.date(1955, 12, 6)},
#  {'Nombre': 'Thomas',
#   'Apellido': 'Burke',
#   'Dirección': '08735 Carson Camp\nLake Nancymouth, AL 15207',
#   'Correo electrónico': 'alison90@example.org',
#   'Fecha de nacimiento': datetime.date(1935, 11, 21)},
#  {'Nombre': 'Stephanie',
#   'Apellido': 'Hunt',
#   'Dirección': '962 Thomas Shoal\nEast Robertchester, TN 56296',
#   'Correo electrónico': 'wellsbrianna@example.com',
#   'Fecha de nacimiento': datetime.date(1928, 10, 25)},
#  {'Nombre': 'Jodi',
#   'Apellido': 'Klein',
#   'Dirección': '2947 Tyler Ville\nKatiebury, FM 66078',
#   'Correo electrónico': 'corywelch@example.com',
#   'Fecha de nacimiento': datetime.date(2018, 5, 28)},
#  {'Nombre': 'Timothy',
#   'Apellido': 'Smith',
#   'Dirección': '8546 Mcgee Keys Suite 350\nNorth Erin, UT 94960',
#   'Correo electrónico': 'vanessa28@example.net',
#   'Fecha de nacimiento': datetime.date(1999, 5, 5)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Howell',
#   'Dirección': '1453 Cuevas Place\nPort Johnchester, WA 24606',
#   'Correo electrónico': 'qwilliams@example.com',
#   'Fecha de nacimiento': datetime.date(1997, 6, 4)},
#  {'Nombre': 'George',
#   'Apellido': 'Richardson',
#   'Dirección': '79662 Navarro Canyon Apt. 287\nChristineside, MN 28069',
#   'Correo electrónico': 'twright@example.net',
#   'Fecha de nacimiento': datetime.date(1976, 12, 16)},
#  {'Nombre': 'Theresa',
#   'Apellido': 'Andrews',
#   'Dirección': '411 Mary Forge\nPotterville, PR 14916',
#   'Correo electrónico': 'apoole@example.com',
#   'Fecha de nacimiento': datetime.date(2013, 2, 27)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Garrett',
#   'Dirección': '09402 Bates Squares\nPeterbury, OK 03025',
#   'Correo electrónico': 'joshuaharmon@example.org',
#   'Fecha de nacimiento': datetime.date(1985, 10, 7)},
#  {'Nombre': 'Mitchell',
#   'Apellido': 'Dickerson',
#   'Dirección': '97802 Cunningham Shoals Suite 748\nEwingland, MT 07689',
#   'Correo electrónico': 'jacksonbrandi@example.net',
#   'Fecha de nacimiento': datetime.date(2016, 3, 29)},
#  {'Nombre': 'Teresa',
#   'Apellido': 'Jenkins',
#   'Dirección': '36384 Bruce Falls\nTonystad, MH 95774',
#   'Correo electrónico': 'sgarcia@example.org',
#   'Fecha de nacimiento': datetime.date(1976, 6, 23)},
#  {'Nombre': 'Cory',
#   'Apellido': 'Hicks',
#   'Dirección': '54043 James Prairie Apt. 608\nPort Edwardburgh, MS 65917',
#   'Correo electrónico': 'anthonyromero@example.net',
#   'Fecha de nacimiento': datetime.date(1917, 11, 15)},
#  {'Nombre': 'Anna',
#   'Apellido': 'Flores',
#   'Dirección': '321 Shawn Isle Suite 887\nChristophermouth, AK 53648',
#   'Correo electrónico': 'jonesbryan@example.com',
#   'Fecha de nacimiento': datetime.date(2014, 3, 18)},
#  {'Nombre': 'Kathleen',
#   'Apellido': 'Bailey',
#   'Dirección': 'PSC 7951, Box 1316\nAPO AE 91175',
#   'Correo electrónico': 'livingstoncarolyn@example.com',
#   'Fecha de nacimiento': datetime.date(1964, 11, 18)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Keller',
#   'Dirección': 'Unit 1514 Box 9948\nDPO AA 31885',
#   'Correo electrónico': 'david37@example.net',
#   'Fecha de nacimiento': datetime.date(1994, 3, 4)},
#  {'Nombre': 'Larry',
#   'Apellido': 'Munoz',
#   'Dirección': '003 Crawford Forges Suite 084\nNelsonport, IA 41512',
#   'Correo electrónico': 'jennifer21@example.org',
#   'Fecha de nacimiento': datetime.date(1962, 2, 2)},
#  {'Nombre': 'Angela',
#   'Apellido': 'Herrera',
#   'Dirección': '30312 Jacqueline Villages Apt. 875\nAmyport, GU 88429',
#   'Correo electrónico': 'jimmyrobinson@example.net',
#   'Fecha de nacimiento': datetime.date(2000, 1, 24)},
#  {'Nombre': 'Charles',
#   'Apellido': 'Jimenez',
#   'Dirección': '8747 Lane Views Suite 162\nNew Jamesmouth, MS 35739',
#   'Correo electrónico': 'jose40@example.com',
#   'Fecha de nacimiento': datetime.date(1927, 6, 11)},
#  {'Nombre': 'Mary',
#   'Apellido': 'Lutz',
#   'Dirección': '394 Jennifer View Apt. 532\nDouglasport, AZ 37868',
#   'Correo electrónico': 'craigwood@example.org',
#   'Fecha de nacimiento': datetime.date(1930, 1, 30)},
#  {'Nombre': 'Jim',
#   'Apellido': 'Barrett',
#   'Dirección': '304 Shawna Estate\nPort Colleen, KS 65554',
#   'Correo electrónico': 'erik81@example.com',
#   'Fecha de nacimiento': datetime.date(1927, 8, 6)},
#  {'Nombre': 'Janet',
#   'Apellido': 'Bishop',
#   'Dirección': '7542 Charles Port\nSouth Cynthia, AR 04899',
#   'Correo electrónico': 'jeanne23@example.com',
#   'Fecha de nacimiento': datetime.date(2008, 5, 15)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Fisher',
#   'Dirección': '805 David Lock Suite 363\nPort Jessica, MS 18746',
#   'Correo electrónico': 'ubrock@example.com',
#   'Fecha de nacimiento': datetime.date(1952, 8, 13)},
#  {'Nombre': 'Nicole',
#   'Apellido': 'Tran',
#   'Dirección': '5149 Amy Mountain\nLake Anthony, FM 95844',
#   'Correo electrónico': 'rosarioleonard@example.org',
#   'Fecha de nacimiento': datetime.date(1993, 10, 20)},
#  {'Nombre': 'Alicia',
#   'Apellido': 'Smith',
#   'Dirección': '62419 Michelle Cape Apt. 516\nSheilafort, GA 02699',
#   'Correo electrónico': 'nortonthomas@example.com',
#   'Fecha de nacimiento': datetime.date(1917, 1, 7)},
#  {'Nombre': 'Jerome',
#   'Apellido': 'Haynes',
#   'Dirección': '393 Garcia Burgs Apt. 972\nHeathtown, RI 45750',
#   'Correo electrónico': 'wheelerkelsey@example.com',
#   'Fecha de nacimiento': datetime.date(2005, 6, 26)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Brown',
#   'Dirección': '4658 Kimberly Club\nPort Brandymouth, KS 57064',
#   'Correo electrónico': 'acruz@example.com',
#   'Fecha de nacimiento': datetime.date(1912, 12, 22)},
#  {'Nombre': 'Sandra',
#   'Apellido': 'Long',
#   'Dirección': '614 Williams Grove Apt. 820\nDanaside, MN 24880',
#   'Correo electrónico': 'kristinakelly@example.net',
#   'Fecha de nacimiento': datetime.date(1957, 6, 13)},
#  {'Nombre': 'Heather',
#   'Apellido': 'Hubbard',
#   'Dirección': 'USNV Smith\nFPO AA 62061',
#   'Correo electrónico': 'rruiz@example.com',
#   'Fecha de nacimiento': datetime.date(1921, 1, 15)},
#  {'Nombre': 'Jessica',
#   'Apellido': 'Payne',
#   'Dirección': '78929 Casey Points\nMorrisborough, MT 48481',
#   'Correo electrónico': 'brenda55@example.net',
#   'Fecha de nacimiento': datetime.date(1968, 3, 17)},
#  {'Nombre': 'Paul',
#   'Apellido': 'Mejia',
#   'Dirección': '61932 Joshua Orchard Apt. 033\nSouth Brett, SC 38201',
#   'Correo electrónico': 'trevorlewis@example.net',
#   'Fecha de nacimiento': datetime.date(1927, 1, 13)},
#  {'Nombre': 'Zachary',
#   'Apellido': 'Simmons',
#   'Dirección': '4055 Smith Crescent Suite 518\nPittsside, AL 29341',
#   'Correo electrónico': 'amy32@example.net',
#   'Fecha de nacimiento': datetime.date(1989, 12, 13)},
#  {'Nombre': 'Mary',
#   'Apellido': 'White',
#   'Dirección': '9913 Kristi Track\nJohnmouth, GA 96004',
#   'Correo electrónico': 'darlenespencer@example.net',
#   'Fecha de nacimiento': datetime.date(2009, 5, 24)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Barrett',
#   'Dirección': '296 Campbell Pass\nSouth Michelle, OH 10572',
#   'Correo electrónico': 'tranteresa@example.net',
#   'Fecha de nacimiento': datetime.date(1946, 7, 2)},
#  {'Nombre': 'Amanda',
#   'Apellido': 'White',
#   'Dirección': '05372 Charlotte Garden Suite 727\nJamesville, CT 86987',
#   'Correo electrónico': 'ijohnson@example.net',
#   'Fecha de nacimiento': datetime.date(1988, 5, 1)},
#  {'Nombre': 'John',
#   'Apellido': 'Browning',
#   'Dirección': '0674 Beltran Path Suite 705\nNew Georgeberg, MO 70375',
#   'Correo electrónico': 'trujillovictor@example.org',
#   'Fecha de nacimiento': datetime.date(1998, 7, 15)},
#  {'Nombre': 'Devin',
#   'Apellido': 'Watkins',
#   'Dirección': '173 Samantha Stravenue Apt. 988\nPaulport, TN 82992',
#   'Correo electrónico': 'scott54@example.net',
#   'Fecha de nacimiento': datetime.date(1920, 2, 27)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Marquez',
#   'Dirección': '57962 Garrison Lane\nPort Veronica, PW 62720',
#   'Correo electrónico': 'heatherandrade@example.net',
#   'Fecha de nacimiento': datetime.date(1991, 3, 30)},
#  {'Nombre': 'Christine',
#   'Apellido': 'Mendoza',
#   'Dirección': '468 Brown Rapid Suite 355\nWest Christineburgh, AR 48585',
#   'Correo electrónico': 'rmcintosh@example.com',
#   'Fecha de nacimiento': datetime.date(1914, 10, 29)},
#  {'Nombre': 'Kevin',
#   'Apellido': 'Smith',
#   'Dirección': '8469 Penny Extensions\nMillsburgh, UT 26781',
#   'Correo electrónico': 'thomasmaria@example.net',
#   'Fecha de nacimiento': datetime.date(1923, 12, 17)},
#  {'Nombre': 'Benjamin',
#   'Apellido': 'Munoz',
#   'Dirección': '7737 Simpson Tunnel\nThomasmouth, CO 92767',
#   'Correo electrónico': 'orodgers@example.org',
#   'Fecha de nacimiento': datetime.date(1981, 12, 14)},
#  {'Nombre': 'Katherine',
#   'Apellido': 'Howard',
#   'Dirección': '755 Mueller Walk\nEast Alejandramouth, VA 90016',
#   'Correo electrónico': 'cathymartinez@example.org',
#   'Fecha de nacimiento': datetime.date(1984, 1, 22)},
#  {'Nombre': 'Emily',
#   'Apellido': 'Young',
#   'Dirección': '84794 Thomas Park Suite 578\nReedmouth, NY 49738',
#   'Correo electrónico': 'timothy62@example.net',
#   'Fecha de nacimiento': datetime.date(1950, 5, 29)},
#  {'Nombre': 'Joyce',
#   'Apellido': 'Owens',
#   'Dirección': '258 Richard Lodge\nValdezhaven, AZ 57397',
#   'Correo electrónico': 'amyjones@example.com',
#   'Fecha de nacimiento': datetime.date(1953, 1, 13)},
#  {'Nombre': 'Lawrence',
#   'Apellido': 'Brown',
#   'Dirección': '010 Danielle Point Suite 414\nEast Kevinview, AK 01563',
#   'Correo electrónico': 'carla01@example.org',
#   'Fecha de nacimiento': datetime.date(1934, 8, 22)},
#  {'Nombre': 'Kristopher',
#   'Apellido': 'Sanchez',
#   'Dirección': '72392 William Shoals\nDrakefort, ID 46925',
#   'Correo electrónico': 'leecarol@example.net',
#   'Fecha de nacimiento': datetime.date(1965, 11, 26)},
#  {'Nombre': 'Stephanie',
#   'Apellido': 'Miller',
#   'Dirección': '862 Mark Divide Suite 726\nRachelchester, MI 87194',
#   'Correo electrónico': 'kellywalter@example.org',
#   'Fecha de nacimiento': datetime.date(2020, 4, 13)},
#  {'Nombre': 'Ryan',
#   'Apellido': 'Anderson',
#   'Dirección': '186 Johnson Prairie\nWest Kelsey, NC 08541',
#   'Correo electrónico': 'ruizryan@example.org',
#   'Fecha de nacimiento': datetime.date(1949, 10, 26)},
#  {'Nombre': 'Judith',
#   'Apellido': 'Lopez',
#   'Dirección': '5518 Caroline Corners Apt. 062\nWest Jenniferborough, MA 37142',
#   'Correo electrónico': 'bookertimothy@example.org',
#   'Fecha de nacimiento': datetime.date(2004, 3, 29)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Bryant',
#   'Dirección': '99732 Meyer Orchard\nNew Carly, CO 72291',
#   'Correo electrónico': 'barkeramber@example.net',
#   'Fecha de nacimiento': datetime.date(1966, 6, 20)},
#  {'Nombre': 'Jeremy',
#   'Apellido': 'Fernandez',
#   'Dirección': '692 Brown Flat Suite 390\nJaredville, OH 44738',
#   'Correo electrónico': 'jacksonnicole@example.com',
#   'Fecha de nacimiento': datetime.date(1945, 5, 17)},
#  {'Nombre': 'Ralph',
#   'Apellido': 'Rodriguez',
#   'Dirección': '848 Kayla Views\nPort Josephhaven, VA 54735',
#   'Correo electrónico': 'josephelliott@example.com',
#   'Fecha de nacimiento': datetime.date(1966, 11, 28)},
#  {'Nombre': 'Frank',
#   'Apellido': 'Harris',
#   'Dirección': '83939 Reginald Mews\nWest Johnport, VT 16549',
#   'Correo electrónico': 'jessica56@example.org',
#   'Fecha de nacimiento': datetime.date(2002, 3, 8)},
#  {'Nombre': 'Nicole',
#   'Apellido': 'Gonzales',
#   'Dirección': '846 Gonzalez Plaza\nSouth Robert, SC 21171',
#   'Correo electrónico': 'castanedaheather@example.com',
#   'Fecha de nacimiento': datetime.date(1978, 4, 30)},
#  {'Nombre': 'Veronica',
#   'Apellido': 'Vasquez',
#   'Dirección': 'USCGC Skinner\nFPO AP 91931',
#   'Correo electrónico': 'woodsmartha@example.net',
#   'Fecha de nacimiento': datetime.date(1997, 11, 27)},
#  {'Nombre': 'Erin',
#   'Apellido': 'Waters',
#   'Dirección': '13289 Myers Road\nSheltonmouth, VI 90181',
#   'Correo electrónico': 'ebarber@example.org',
#   'Fecha de nacimiento': datetime.date(1911, 7, 31)},
#  {'Nombre': 'Willie',
#   'Apellido': 'White',
#   'Dirección': '687 Richard Well Suite 337\nNew Angelashire, PA 55340',
#   'Correo electrónico': 'adean@example.com',
#   'Fecha de nacimiento': datetime.date(1958, 12, 30)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Gross',
#   'Dirección': '7718 Jenkins Keys Suite 721\nHinesberg, ME 59325',
#   'Correo electrónico': 'fishermark@example.org',
#   'Fecha de nacimiento': datetime.date(1945, 2, 16)},
#  {'Nombre': 'Maureen',
#   'Apellido': 'Hawkins',
#   'Dirección': '99703 Edward Groves Suite 248\nPort Donnaport, UT 42877',
#   'Correo electrónico': 'cooperpatricia@example.org',
#   'Fecha de nacimiento': datetime.date(1989, 7, 16)},
#  {'Nombre': 'Craig',
#   'Apellido': 'Lamb',
#   'Dirección': '30136 Brock Inlet\nNew Adamside, MO 83750',
#   'Correo electrónico': 'marciabrown@example.org',
#   'Fecha de nacimiento': datetime.date(1970, 1, 21)},
#  {'Nombre': 'Brandon',
#   'Apellido': 'Nunez',
#   'Dirección': '64971 Madison Forest Suite 072\nEast Edwardstad, NM 88558',
#   'Correo electrónico': 'carrie51@example.net',
#   'Fecha de nacimiento': datetime.date(1950, 9, 1)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Olson',
#   'Dirección': '678 Kevin Lodge\nCunninghamfurt, ID 03322',
#   'Correo electrónico': 'gfreeman@example.com',
#   'Fecha de nacimiento': datetime.date(1975, 1, 9)},
#  {'Nombre': 'Gregory',
#   'Apellido': 'Long',
#   'Dirección': '32645 Amanda Freeway\nWest Katrina, NY 75975',
#   'Correo electrónico': 'millerchristopher@example.net',
#   'Fecha de nacimiento': datetime.date(1947, 11, 7)},
#  {'Nombre': 'Natalie',
#   'Apellido': 'Barnes',
#   'Dirección': '984 Julie Place Suite 569\nRobertside, VI 83596',
#   'Correo electrónico': 'alyssa76@example.net',
#   'Fecha de nacimiento': datetime.date(1956, 12, 10)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Daniels',
#   'Dirección': '42922 Lam Highway\nMoralesmouth, WY 36545',
#   'Correo electrónico': 'ohardin@example.org',
#   'Fecha de nacimiento': datetime.date(1983, 10, 4)},
#  {'Nombre': 'Zachary',
#   'Apellido': 'Morton',
#   'Dirección': '8668 Jennifer Plains Apt. 863\nAmberbury, VT 91255',
#   'Correo electrónico': 'lynntyler@example.com',
#   'Fecha de nacimiento': datetime.date(1941, 3, 26)},
#  {'Nombre': 'Daniel',
#   'Apellido': 'Richardson',
#   'Dirección': '08109 Ochoa Club\nNorth Davidhaven, DC 63421',
#   'Correo electrónico': 'xguerra@example.org',
#   'Fecha de nacimiento': datetime.date(1990, 1, 6)},
#  {'Nombre': 'Xavier',
#   'Apellido': 'Richards',
#   'Dirección': '024 Bethany Brook Apt. 307\nJosephland, MO 84293',
#   'Correo electrónico': 'tiffany10@example.net',
#   'Fecha de nacimiento': datetime.date(1918, 12, 9)},
#  {'Nombre': 'Cory',
#   'Apellido': 'English',
#   'Dirección': '169 Wade Drive\nElliottshire, TX 17477',
#   'Correo electrónico': 'curtiseric@example.com',
#   'Fecha de nacimiento': datetime.date(1919, 12, 16)},
#  {'Nombre': 'Steven',
#   'Apellido': 'Anderson',
#   'Dirección': '0092 David Dam\nPaigeport, GU 30827',
#   'Correo electrónico': 'elijahharris@example.org',
#   'Fecha de nacimiento': datetime.date(1912, 8, 1)},
#  {'Nombre': 'Emily',
#   'Apellido': 'Brown',
#   'Dirección': 'Unit 6722 Box 6924\nDPO AP 41893',
#   'Correo electrónico': 'raylawrence@example.net',
#   'Fecha de nacimiento': datetime.date(1996, 6, 26)},
#  {'Nombre': 'Brittany',
#   'Apellido': 'Porter',
#   'Dirección': '655 Hannah Locks Apt. 188\nLake Andre, SD 13536',
#   'Correo electrónico': 'edward76@example.net',
#   'Fecha de nacimiento': datetime.date(1939, 12, 10)},
#  {'Nombre': 'Katrina',
#   'Apellido': 'Wells',
#   'Dirección': '630 Willis Lodge Apt. 351\nEast Cathy, CA 76581',
#   'Correo electrónico': 'pmurray@example.net',
#   'Fecha de nacimiento': datetime.date(2018, 1, 1)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Jennings',
#   'Dirección': '23895 David Knoll\nEast David, IA 41369',
#   'Correo electrónico': 'rose39@example.net',
#   'Fecha de nacimiento': datetime.date(1982, 8, 13)},
#  {'Nombre': 'Jessica',
#   'Apellido': 'Kemp',
#   'Dirección': '5003 Charles Mills Apt. 946\nNew Vincentport, GU 03363',
#   'Correo electrónico': 'elizabethball@example.net',
#   'Fecha de nacimiento': datetime.date(1961, 11, 25)},
#  {'Nombre': 'Rebecca',
#   'Apellido': 'Haynes',
#   'Dirección': '304 Parker Gateway\nDuncanton, KS 83677',
#   'Correo electrónico': 'davisrobert@example.net',
#   'Fecha de nacimiento': datetime.date(1978, 4, 23)},
#  {'Nombre': 'Paul',
#   'Apellido': 'Kim',
#   'Dirección': '61251 Ashley Avenue Apt. 063\nSouth Wayneview, NC 13262',
#   'Correo electrónico': 'jacobwalters@example.org',
#   'Fecha de nacimiento': datetime.date(1926, 1, 18)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Kim',
#   'Dirección': '974 Heather Inlet Apt. 512\nMaryport, TX 79252',
#   'Correo electrónico': 'diana12@example.net',
#   'Fecha de nacimiento': datetime.date(1982, 2, 7)},
#  {'Nombre': 'April',
#   'Apellido': 'Jackson',
#   'Dirección': '53585 Eric Flats Apt. 855\nJordanchester, AL 47617',
#   'Correo electrónico': 'imcdowell@example.org',
#   'Fecha de nacimiento': datetime.date(1994, 3, 28)},
#  {'Nombre': 'Angela',
# ...
#   'Correo electrónico': 'udowns@example.net',
#   'Fecha de nacimiento': datetime.date(1909, 9, 14)},
#  {'Nombre': 'Corey',
#   'Apellido': 'Elliott',
#   'Dirección': '404 Vincent Keys Suite 689\nDominiqueton, CO 53903',
#   'Correo electrónico': 'haley29@example.net',
#   'Fecha de nacimiento': datetime.date(1916, 10, 25)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Parker',
#   'Dirección': 'Unit 3684 Box 8093\nDPO AA 06056',
#   'Correo electrónico': 'jonesjacqueline@example.org',
#   'Fecha de nacimiento': datetime.date(1913, 9, 7)},
#  {'Nombre': 'Marie',
#   'Apellido': 'Kelly',
#   'Dirección': '24359 Hart Stream Apt. 391\nWilliamborough, AK 80547',
#   'Correo electrónico': 'djackson@example.net',
#   'Fecha de nacimiento': datetime.date(1948, 12, 12)},
#  {'Nombre': 'Sandra',
#   'Apellido': 'Ferguson',
#   'Dirección': '87560 Rodriguez Drive Apt. 536\nSouth Brianmouth, DC 84156',
#   'Correo electrónico': 'ericstewart@example.net',
#   'Fecha de nacimiento': datetime.date(1984, 2, 16)},
#  {'Nombre': 'William',
#   'Apellido': 'Williams',
#   'Dirección': '105 Marshall Summit\nNorth Kevinmouth, AL 08405',
#   'Correo electrónico': 'jwatkins@example.net',
#   'Fecha de nacimiento': datetime.date(1960, 9, 18)},
#  {'Nombre': 'John',
#   'Apellido': 'Davis',
#   'Dirección': '46168 Hernandez Terrace Suite 429\nRodriguezport, AS 62219',
#   'Correo electrónico': 'jtucker@example.com',
#   'Fecha de nacimiento': datetime.date(2010, 7, 12)},
#  {'Nombre': 'William',
#   'Apellido': 'Nash',
#   'Dirección': '120 Charles Fords\nBrandonhaven, MO 03621',
#   'Correo electrónico': 'joelreyes@example.net',
#   'Fecha de nacimiento': datetime.date(1931, 5, 24)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Coleman',
#   'Dirección': '103 Nathaniel Overpass\nCastilloside, UT 87539',
#   'Correo electrónico': 'troybennett@example.org',
#   'Fecha de nacimiento': datetime.date(1974, 2, 12)},
#  {'Nombre': 'Charles',
#   'Apellido': 'Gonzales',
#   'Dirección': '4827 Mark Forge Apt. 234\nAguilartown, DE 62864',
#   'Correo electrónico': 'gomezderrick@example.net',
#   'Fecha de nacimiento': datetime.date(1927, 6, 24)},
#  {'Nombre': 'Barbara',
#   'Apellido': 'Matthews',
#   'Dirección': '81798 William Islands\nJohnsonbury, IA 13905',
#   'Correo electrónico': 'dcarey@example.com',
#   'Fecha de nacimiento': datetime.date(1994, 4, 4)},
#  {'Nombre': 'James',
#   'Apellido': 'Morris',
#   'Dirección': '2221 Torres Extensions\nJoshuaville, VI 82869',
#   'Correo electrónico': 'mcneilangela@example.net',
#   'Fecha de nacimiento': datetime.date(1941, 1, 1)},
#  {'Nombre': 'Richard',
#   'Apellido': 'Stephens',
#   'Dirección': '31131 Jordan Villages Apt. 362\nFrazierport, MI 50049',
#   'Correo electrónico': 'jessicaromero@example.org',
#   'Fecha de nacimiento': datetime.date(2006, 2, 17)},
#  {'Nombre': 'John',
#   'Apellido': 'Brown',
#   'Dirección': '00271 Kristen Parks Apt. 738\nNorth Sarah, RI 80166',
#   'Correo electrónico': 'jonathanmays@example.com',
#   'Fecha de nacimiento': datetime.date(1919, 8, 29)},
#  {'Nombre': 'Jackie',
#   'Apellido': 'Maxwell',
#   'Dirección': '84286 Rhonda Inlet\nHendersonmouth, HI 56464',
#   'Correo electrónico': 'hhensley@example.com',
#   'Fecha de nacimiento': datetime.date(1985, 8, 12)},
#  {'Nombre': 'Anthony',
#   'Apellido': 'Mathis',
#   'Dirección': '4903 Michael Drive\nSouth Joanne, TN 35335',
#   'Correo electrónico': 'nwilkerson@example.org',
#   'Fecha de nacimiento': datetime.date(1989, 6, 24)},
#  {'Nombre': 'Jennifer',
#   'Apellido': 'Reynolds',
#   'Dirección': '039 Ward Dam\nRodriguezmouth, NY 87431',
#   'Correo electrónico': 'lewisdaniel@example.net',
#   'Fecha de nacimiento': datetime.date(1923, 10, 1)},
#  {'Nombre': 'Derrick',
#   'Apellido': 'Obrien',
#   'Dirección': '13462 Walker View\nBraunland, GU 83409',
#   'Correo electrónico': 'roberthernandez@example.net',
#   'Fecha de nacimiento': datetime.date(1997, 5, 18)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Moore',
#   'Dirección': '512 Karen Lodge\nWest Kellymouth, NM 92823',
#   'Correo electrónico': 'katherineoconnell@example.com',
#   'Fecha de nacimiento': datetime.date(1938, 1, 7)},
#  {'Nombre': 'Chad',
#   'Apellido': 'Davis',
#   'Dirección': '21502 Whitney Inlet\nYatesshire, WI 10686',
#   'Correo electrónico': 'michaelgiles@example.com',
#   'Fecha de nacimiento': datetime.date(1914, 1, 18)},
#  {'Nombre': 'Erica',
#   'Apellido': 'Hall',
#   'Dirección': '76228 Gabriela Meadow Suite 958\nCharlesborough, KY 33604',
#   'Correo electrónico': 'maria50@example.net',
#   'Fecha de nacimiento': datetime.date(1985, 12, 7)},
#  {'Nombre': 'Courtney',
#   'Apellido': 'French',
#   'Dirección': 'Unit 0832 Box 1770\nDPO AP 05207',
#   'Correo electrónico': 'emack@example.org',
#   'Fecha de nacimiento': datetime.date(1929, 9, 16)},
#  {'Nombre': 'Ralph',
#   'Apellido': 'Brewer',
#   'Dirección': '338 Christopher Tunnel\nBrendatown, MD 02029',
#   'Correo electrónico': 'guzmanernest@example.net',
#   'Fecha de nacimiento': datetime.date(1918, 5, 11)},
#  {'Nombre': 'James',
#   'Apellido': 'Friedman',
#   'Dirección': '47115 Rivers Manor\nPort Jasmine, TX 05026',
#   'Correo electrónico': 'martinlisa@example.net',
#   'Fecha de nacimiento': datetime.date(1967, 4, 3)},
#  {'Nombre': 'Melissa',
#   'Apellido': 'Barnett',
#   'Dirección': '654 Nelson Creek Suite 056\nSouth Wendyside, MA 03071',
#   'Correo electrónico': 'richardsonpatricia@example.com',
#   'Fecha de nacimiento': datetime.date(1974, 12, 4)},
#  {'Nombre': 'Jillian',
#   'Apellido': 'Mitchell',
#   'Dirección': '36473 Clark Circles Apt. 997\nNorth Lisa, NM 90759',
#   'Correo electrónico': 'elloyd@example.net',
#   'Fecha de nacimiento': datetime.date(2007, 8, 15)},
#  {'Nombre': 'Pamela',
#   'Apellido': 'Thompson',
#   'Dirección': '343 Kelly Roads Suite 585\nSouth Jamesshire, VA 82935',
#   'Correo electrónico': 'williamwilkins@example.com',
#   'Fecha de nacimiento': datetime.date(1918, 11, 19)},
#  {'Nombre': 'Jessica',
#   'Apellido': 'Berry',
#   'Dirección': '3422 David Spur\nJeremiahville, NE 36117',
#   'Correo electrónico': 'abbottbeth@example.org',
#   'Fecha de nacimiento': datetime.date(1937, 2, 2)},
#  {'Nombre': 'David',
#   'Apellido': 'Ward',
#   'Dirección': '43380 Cooper Locks\nBarryfurt, MH 03062',
#   'Correo electrónico': 'amanda41@example.org',
#   'Fecha de nacimiento': datetime.date(1973, 11, 25)},
#  {'Nombre': 'Jeremiah',
#   'Apellido': 'Pena',
#   'Dirección': '3947 Foster Ville\nHarmonberg, GU 90449',
#   'Correo electrónico': 'tara17@example.net',
#   'Fecha de nacimiento': datetime.date(1971, 3, 6)},
#  {'Nombre': 'Brittany',
#   'Apellido': 'Parker',
#   'Dirección': '7400 Kim Fork\nMooreberg, MA 35225',
#   'Correo electrónico': 'swarner@example.net',
#   'Fecha de nacimiento': datetime.date(1915, 2, 1)},
#  {'Nombre': 'Brian',
#   'Apellido': 'Rhodes',
#   'Dirección': '4604 Chad Estate\nMaloneburgh, NV 29347',
#   'Correo electrónico': 'jose34@example.net',
#   'Fecha de nacimiento': datetime.date(1933, 4, 22)},
#  {'Nombre': 'Peggy',
#   'Apellido': 'Joseph',
#   'Dirección': '6593 David Gardens\nPort Brenda, VI 01729',
#   'Correo electrónico': 'sullivanwilliam@example.org',
#   'Fecha de nacimiento': datetime.date(1952, 1, 15)},
#  {'Nombre': 'Alexander',
#   'Apellido': 'Hart',
#   'Dirección': '80665 Williams Mount\nNew Amber, VI 54663',
#   'Correo electrónico': 'bonniethompson@example.org',
#   'Fecha de nacimiento': datetime.date(1969, 10, 4)},
#  {'Nombre': 'Katherine',
#   'Apellido': 'Smith',
#   'Dirección': '85921 Cathy Isle Apt. 233\nLake Brianna, OR 50419',
#   'Correo electrónico': 'brandonharris@example.net',
#   'Fecha de nacimiento': datetime.date(1968, 1, 12)},
#  {'Nombre': 'William',
#   'Apellido': 'Levine',
#   'Dirección': '6353 David Estates Suite 192\nWest Christie, TN 37664',
#   'Correo electrónico': 'smithtiffany@example.com',
#   'Fecha de nacimiento': datetime.date(1969, 3, 21)},
#  {'Nombre': 'Karen',
#   'Apellido': 'Morgan',
#   'Dirección': '418 May Stream Apt. 006\nEast Patricia, MN 52011',
#   'Correo electrónico': 'carolyn60@example.org',
#   'Fecha de nacimiento': datetime.date(2022, 10, 28)},
#  {'Nombre': 'Dale',
#   'Apellido': 'Tyler',
#   'Dirección': '2253 Anne Brooks Suite 140\nWrightberg, ND 36827',
#   'Correo electrónico': 'evelyn89@example.org',
#   'Fecha de nacimiento': datetime.date(2012, 10, 19)},
#  {'Nombre': 'Sandra',
#   'Apellido': 'Logan',
#   'Dirección': '8399 Johnson Ramp Apt. 738\nPetersonborough, IL 38312',
#   'Correo electrónico': 'philipjohnson@example.org',
#   'Fecha de nacimiento': datetime.date(2016, 11, 6)},
#  {'Nombre': 'Vicki',
#   'Apellido': 'Mcclure',
#   'Dirección': '15873 Mark Glens Suite 779\nSouth Stephanie, AR 13331',
#   'Correo electrónico': 'tiffanyvelasquez@example.net',
#   'Fecha de nacimiento': datetime.date(1921, 4, 21)},
#  {'Nombre': 'Bryan',
#   'Apellido': 'Cook',
#   'Dirección': '9769 Mitchell Course\nWest Briantown, OH 18831',
#   'Correo electrónico': 'wilsoncraig@example.org',
#   'Fecha de nacimiento': datetime.date(1980, 4, 6)},
#  {'Nombre': 'Brenda',
#   'Apellido': 'Walker',
#   'Dirección': '5052 Bryant Wall Suite 760\nNew Oscarburgh, DC 40991',
#   'Correo electrónico': 'timothystewart@example.com',
#   'Fecha de nacimiento': datetime.date(1990, 5, 3)},
#  {'Nombre': 'Samantha',
#   'Apellido': 'Miller',
#   'Dirección': '9849 George Fords Suite 513\nFranciscoton, TN 95270',
#   'Correo electrónico': 'matthewpalmer@example.com',
#   'Fecha de nacimiento': datetime.date(2023, 4, 4)},
#  {'Nombre': 'Karen',
#   'Apellido': 'Mcdonald',
#   'Dirección': '1947 Benjamin Curve\nNorth Sierraville, KS 95593',
#   'Correo electrónico': 'greerapril@example.org',
#   'Fecha de nacimiento': datetime.date(1972, 11, 16)},
#  {'Nombre': 'Amber',
#   'Apellido': 'Robertson',
#   'Dirección': '770 Brian Trail\nTannermouth, GU 55469',
#   'Correo electrónico': 'marellano@example.net',
#   'Fecha de nacimiento': datetime.date(1929, 6, 3)},
#  {'Nombre': 'Linda',
#   'Apellido': 'Freeman',
#   'Dirección': '0256 Mitchell Mission Suite 360\nFergusonville, WI 01360',
#   'Correo electrónico': 'lrocha@example.com',
#   'Fecha de nacimiento': datetime.date(2004, 6, 6)},
#  {'Nombre': 'Kristin',
#   'Apellido': 'Wood',
#   'Dirección': '01431 David Summit\nBenjaminborough, CO 01525',
#   'Correo electrónico': 'sarahrivas@example.net',
#   'Fecha de nacimiento': datetime.date(1932, 1, 29)},
#  {'Nombre': 'Christina',
#   'Apellido': 'Parks',
#   'Dirección': 'USS Nixon\nFPO AE 14674',
#   'Correo electrónico': 'tony19@example.org',
#   'Fecha de nacimiento': datetime.date(1956, 12, 21)},
#  {'Nombre': 'Matthew',
#   'Apellido': 'Horton',
#   'Dirección': '947 Jenna Ford\nJenniferstad, TX 38263',
#   'Correo electrónico': 'ogonzales@example.org',
#   'Fecha de nacimiento': datetime.date(1919, 2, 19)},
#  {'Nombre': 'Jonathan',
#   'Apellido': 'Williams',
#   'Dirección': '446 Simmons Shoal Apt. 407\nPerezstad, CA 21378',
#   'Correo electrónico': 'melinda81@example.net',
#   'Fecha de nacimiento': datetime.date(1958, 5, 14)},
#  {'Nombre': 'Gloria',
#   'Apellido': 'Davis',
#   'Dirección': 'Unit 3000 Box 6770\nDPO AA 08141',
#   'Correo electrónico': 'ochoaemily@example.com',
#   'Fecha de nacimiento': datetime.date(1985, 8, 8)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Lam',
#   'Dirección': '20144 Olivia Manors Suite 477\nTinafort, AK 56028',
#   'Correo electrónico': 'shines@example.com',
#   'Fecha de nacimiento': datetime.date(1995, 10, 8)},
#  {'Nombre': 'Curtis',
#   'Apellido': 'Chavez',
#   'Dirección': '90981 Riley Villages\nStephenview, PW 61700',
#   'Correo electrónico': 'elowery@example.com',
#   'Fecha de nacimiento': datetime.date(2018, 11, 25)},
#  {'Nombre': 'Amy',
#   'Apellido': 'Sims',
#   'Dirección': '42648 Walton Brook\nNorth Debbie, WA 46431',
#   'Correo electrónico': 'alyssaward@example.net',
#   'Fecha de nacimiento': datetime.date(1932, 8, 4)},
#  {'Nombre': 'Sue',
#   'Apellido': 'Roberts',
#   'Dirección': '3491 Burke Well Apt. 332\nAndrefort, PA 03120',
#   'Correo electrónico': 'richardcampbell@example.org',
#   'Fecha de nacimiento': datetime.date(1975, 11, 30)},
#  {'Nombre': 'Willie',
#   'Apellido': 'Davis',
#   'Dirección': '7583 Melissa Flat Suite 099\nJonathanbury, VA 18546',
#   'Correo electrónico': 'thompsonmatthew@example.net',
#   'Fecha de nacimiento': datetime.date(1946, 7, 10)},
#  {'Nombre': 'Cindy',
#   'Apellido': 'Mcdonald',
#   'Dirección': '88827 Michael Parkways Suite 131\nNorth Jeffreyview, VI 71916',
#   'Correo electrónico': 'jenniferpeterson@example.org',
#   'Fecha de nacimiento': datetime.date(1972, 11, 12)},
#  {'Nombre': 'Connor',
#   'Apellido': 'Carter',
#   'Dirección': 'USS Davis\nFPO AP 00576',
#   'Correo electrónico': 'gilbertjuarez@example.org',
#   'Fecha de nacimiento': datetime.date(1944, 1, 7)},
#  {'Nombre': 'Keith',
#   'Apellido': 'Church',
#   'Dirección': '050 Briana Shores\nHillville, IL 18230',
#   'Correo electrónico': 'rbrown@example.net',
#   'Fecha de nacimiento': datetime.date(1987, 11, 9)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Taylor',
#   'Dirección': '71711 Michelle Bridge\nWilliamfort, SC 60530',
#   'Correo electrónico': 'brownjoshua@example.org',
#   'Fecha de nacimiento': datetime.date(1991, 6, 8)},
#  {'Nombre': 'Kelly',
#   'Apellido': 'Kelly',
#   'Dirección': 'PSC 8906, Box 0369\nAPO AE 60695',
#   'Correo electrónico': 'scottmcdaniel@example.net',
#   'Fecha de nacimiento': datetime.date(1910, 1, 12)},
#  {'Nombre': 'Dustin',
#   'Apellido': 'Jones',
#   'Dirección': '5562 Brandy Drive Suite 301\nBobburgh, FM 28513',
#   'Correo electrónico': 'ericwilliams@example.org',
#   'Fecha de nacimiento': datetime.date(1915, 12, 30)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Clark',
#   'Dirección': '597 Mary Trail\nNew Karenland, VA 22147',
#   'Correo electrónico': 'bretthartman@example.net',
#   'Fecha de nacimiento': datetime.date(1940, 6, 17)},
#  {'Nombre': 'Kimberly',
#   'Apellido': 'Noble',
#   'Dirección': 'PSC 7534, Box 9158\nAPO AE 20786',
#   'Correo electrónico': 'stephaniemathis@example.net',
#   'Fecha de nacimiento': datetime.date(1971, 12, 26)},
#  {'Nombre': 'Lee',
#   'Apellido': 'Griffin',
#   'Dirección': '311 Jacob Lane Suite 069\nHarringtonborough, WI 91283',
#   'Correo electrónico': 'joseph72@example.com',
#   'Fecha de nacimiento': datetime.date(1988, 7, 19)},
#  {'Nombre': 'Robert',
#   'Apellido': 'Robinson',
#   'Dirección': 'USNS Jones\nFPO AA 75482',
#   'Correo electrónico': 'terrijohnston@example.com',
#   'Fecha de nacimiento': datetime.date(1932, 6, 23)},
#  {'Nombre': 'Christian',
#   'Apellido': 'Park',
#   'Dirección': '51505 Butler Well Apt. 470\nHeathmouth, NM 09477',
#   'Correo electrónico': 'justin89@example.org',
#   'Fecha de nacimiento': datetime.date(1991, 12, 15)},
#  {'Nombre': 'Shannon',
#   'Apellido': 'Martinez',
#   'Dirección': '63751 Matthew Streets Apt. 942\nSimpsonland, NY 85620',
#   'Correo electrónico': 'ksmith@example.org',
#   'Fecha de nacimiento': datetime.date(1964, 4, 20)},
#  {'Nombre': 'Laura',
#   'Apellido': 'Castillo',
#   'Dirección': '744 Tammy Club\nPort Paultown, MA 61617',
#   'Correo electrónico': 'elizabeth25@example.org',
#   'Fecha de nacimiento': datetime.date(1927, 4, 27)},
#  {'Nombre': 'Emily',
#   'Apellido': 'Adams',
#   'Dirección': '385 Brett Garden\nHeatherhaven, HI 17394',
#   'Correo electrónico': 'dawnespinoza@example.net',
#   'Fecha de nacimiento': datetime.date(1913, 1, 12)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Mcgee',
#   'Dirección': '313 Lowery Port Suite 141\nPort Johnland, CO 32797',
#   'Correo electrónico': 'patriciaharmon@example.net',
#   'Fecha de nacimiento': datetime.date(1941, 8, 5)},
#  {'Nombre': 'Christopher',
#   'Apellido': 'Boyle',
#   'Dirección': '051 Mercer Mews Apt. 085\nButlermouth, NY 59759',
#   'Correo electrónico': 'christopher00@example.com',
#   'Fecha de nacimiento': datetime.date(2008, 11, 1)},
#  {'Nombre': 'Joseph',
#   'Apellido': 'Griffin',
#   'Dirección': '7827 Samantha Drives\nWest Amandamouth, OK 48139',
#   'Correo electrónico': 'edwardsleon@example.com',
#   'Fecha de nacimiento': datetime.date(1996, 11, 18)},
#  {'Nombre': 'Michael',
#   'Apellido': 'Williams',
#   'Dirección': '2786 Patel Knolls\nValeriefort, HI 69657',
#   'Correo electrónico': 'jodymartin@example.com',
#   'Fecha de nacimiento': datetime.date(2011, 12, 24)},
#  {'Nombre': 'Alexander',
#   'Apellido': 'Ortega',
#   'Dirección': '2044 Chambers Forge Suite 937\nPort Jonathanchester, HI 16273',
#   'Correo electrónico': 'paul21@example.org',
#   'Fecha de nacimiento': datetime.date(1918, 7, 16)}]

# %%
data = pd.DataFrame(lista)

# %%
rango=range(1,len(data)+1)
data.index=rango

# %%
data
# Out:
#            Nombre   Apellido  \
# 1          Samuel  Nicholson
# 2         Jessica    Huffman
# 3         Beverly    Johnson
# 4        Kimberly     Watson
# 5           Linda     Tucker
# ...           ...        ...
# 996       Michael      Mcgee
# 997   Christopher      Boyle
# 998        Joseph    Griffin
# 999       Michael   Williams
# 1000    Alexander     Ortega
#
#                                               Dirección  \
# 1     266 Johnson Rest Apt. 564\nSouth Kristen, NM 8...
# 2                      PSC 9201, Box 4184\nAPO AA 81129
# 3     7732 Roberts Shores Suite 769\nLoganborough, M...
# 4     054 Rodriguez Points Apt. 308\nColechester, SC...
# 5       964 Lucas Key Suite 367\nSanchezville, VA 38199
# ...                                                 ...
# 996   313 Lowery Port Suite 141\nPort Johnland, CO 3...
# 997     051 Mercer Mews Apt. 085\nButlermouth, NY 59759
# 998    7827 Samantha Drives\nWest Amandamouth, OK 48139
# 999            2786 Patel Knolls\nValeriefort, HI 69657
# 1000  2044 Chambers Forge Suite 937\nPort Jonathanch...
#
#                Correo electrónico Fecha de nacimiento
# 1             oharris@example.org          1983-01-07
# 2            xhiggins@example.net          2023-10-31
# 3              jcurry@example.com          1935-10-31
# 4           boydmegan@example.org          1931-09-08
# 5     kaitlynphillips@example.net          1929-10-14
# ...                           ...                 ...
# 996    patriciaharmon@example.net          1941-08-05
# 997     christopher00@example.com          2008-11-01
# 998       edwardsleon@example.com          1996-11-18
# 999        jodymartin@example.com          2011-12-24
# 1000           paul21@example.org          1918-07-16
#
# [1000 rows x 5 columns]

# %%
cedula=1102792826
def generar_cedula(d):
    global cedula
    cedula+=1
    return cedula

# %%
data['Cédula']=data['Nombre'].apply(generar_cedula)

# %%
data = data[['Cédula'] + [col for col in data.columns if col != 'Cédula']]

# %%
data
# Out:
#           Cédula       Nombre   Apellido  \
# 1     1102792827       Samuel  Nicholson
# 2     1102792828      Jessica    Huffman
# 3     1102792829      Beverly    Johnson
# 4     1102792830     Kimberly     Watson
# 5     1102792831        Linda     Tucker
# ...          ...          ...        ...
# 996   1102793822      Michael      Mcgee
# 997   1102793823  Christopher      Boyle
# 998   1102793824       Joseph    Griffin
# 999   1102793825      Michael   Williams
# 1000  1102793826    Alexander     Ortega
#
#                                               Dirección  \
# 1     266 Johnson Rest Apt. 564\nSouth Kristen, NM 8...
# 2                      PSC 9201, Box 4184\nAPO AA 81129
# 3     7732 Roberts Shores Suite 769\nLoganborough, M...
# 4     054 Rodriguez Points Apt. 308\nColechester, SC...
# 5       964 Lucas Key Suite 367\nSanchezville, VA 38199
# ...                                                 ...
# 996   313 Lowery Port Suite 141\nPort Johnland, CO 3...
# 997     051 Mercer Mews Apt. 085\nButlermouth, NY 59759
# 998    7827 Samantha Drives\nWest Amandamouth, OK 48139
# 999            2786 Patel Knolls\nValeriefort, HI 69657
# 1000  2044 Chambers Forge Suite 937\nPort Jonathanch...
#
#                Correo electrónico Fecha de nacimiento
# 1             oharris@example.org          1983-01-07
# 2            xhiggins@example.net          2023-10-31
# 3              jcurry@example.com          1935-10-31
# 4           boydmegan@example.org          1931-09-08
# 5     kaitlynphillips@example.net          1929-10-14
# ...                           ...                 ...
# 996    patriciaharmon@example.net          1941-08-05
# 997     christopher00@example.com          2008-11-01
# 998       edwardsleon@example.com          1996-11-18
# 999        jodymartin@example.com          2011-12-24
# 1000           paul21@example.org          1918-07-16
#
# [1000 rows x 6 columns]

# %%
data.to_csv("data.csv", index=False)

# %%
data_parte1=data.drop(columns=["Correo electrónico","Fecha de nacimiento"],inplace=False)
data_parte2=data.drop(columns=["Nombre","Apellido","Dirección"],inplace=False)

# %%
data_parte1.to_csv("data_parte1.csv", index=False)
data_parte2.to_csv("data_parte2.csv", index=False)

# %%
data_parte1
# Out:
#           Cédula       Nombre   Apellido  \
# 1     1102792827       Samuel  Nicholson
# 2     1102792828      Jessica    Huffman
# 3     1102792829      Beverly    Johnson
# 4     1102792830     Kimberly     Watson
# 5     1102792831        Linda     Tucker
# ...          ...          ...        ...
# 996   1102793822      Michael      Mcgee
# 997   1102793823  Christopher      Boyle
# 998   1102793824       Joseph    Griffin
# 999   1102793825      Michael   Williams
# 1000  1102793826    Alexander     Ortega
#
#                                               Dirección
# 1     266 Johnson Rest Apt. 564\nSouth Kristen, NM 8...
# 2                      PSC 9201, Box 4184\nAPO AA 81129
# 3     7732 Roberts Shores Suite 769\nLoganborough, M...
# 4     054 Rodriguez Points Apt. 308\nColechester, SC...
# 5       964 Lucas Key Suite 367\nSanchezville, VA 38199
# ...                                                 ...
# 996   313 Lowery Port Suite 141\nPort Johnland, CO 3...
# 997     051 Mercer Mews Apt. 085\nButlermouth, NY 59759
# 998    7827 Samantha Drives\nWest Amandamouth, OK 48139
# 999            2786 Patel Knolls\nValeriefort, HI 69657
# 1000  2044 Chambers Forge Suite 937\nPort Jonathanch...
#
# [1000 rows x 4 columns]

# %%
data_parte2
# Out:
#           Cédula           Correo electrónico Fecha de nacimiento
# 1     1102792827          oharris@example.org          1983-01-07
# 2     1102792828         xhiggins@example.net          2023-10-31
# 3     1102792829           jcurry@example.com          1935-10-31
# 4     1102792830        boydmegan@example.org          1931-09-08
# 5     1102792831  kaitlynphillips@example.net          1929-10-14
# ...          ...                          ...                 ...
# 996   1102793822   patriciaharmon@example.net          1941-08-05
# 997   1102793823    christopher00@example.com          2008-11-01
# 998   1102793824      edwardsleon@example.com          1996-11-18
# 999   1102793825       jodymartin@example.com          2011-12-24
# 1000  1102793826           paul21@example.org          1918-07-16
#
# [1000 rows x 3 columns]

# %%
data_parte1_recuperado = pd.read_csv("data_parte1.csv")

# %%
data_parte1_recuperado
data_parte1_recuperado.index=rango
data_parte1_recuperado
# Out:
#           Cédula       Nombre   Apellido  \
# 1     1102792827       Samuel  Nicholson
# 2     1102792828      Jessica    Huffman
# 3     1102792829      Beverly    Johnson
# 4     1102792830     Kimberly     Watson
# 5     1102792831        Linda     Tucker
# ...          ...          ...        ...
# 996   1102793822      Michael      Mcgee
# 997   1102793823  Christopher      Boyle
# 998   1102793824       Joseph    Griffin
# 999   1102793825      Michael   Williams
# 1000  1102793826    Alexander     Ortega
#
#                                               Dirección
# 1     266 Johnson Rest Apt. 564\nSouth Kristen, NM 8...
# 2                      PSC 9201, Box 4184\nAPO AA 81129
# 3     7732 Roberts Shores Suite 769\nLoganborough, M...
# 4     054 Rodriguez Points Apt. 308\nColechester, SC...
# 5       964 Lucas Key Suite 367\nSanchezville, VA 38199
# ...                                                 ...
# 996   313 Lowery Port Suite 141\nPort Johnland, CO 3...
# 997     051 Mercer Mews Apt. 085\nButlermouth, NY 59759
# 998    7827 Samantha Drives\nWest Amandamouth, OK 48139
# 999            2786 Patel Knolls\nValeriefort, HI 69657
# 1000  2044 Chambers Forge Suite 937\nPort Jonathanch...
#
# [1000 rows x 4 columns]

# %%
dataframe_unido=pd.merge(data_parte1_recuperado,data_parte2, on='Cédula')
dataframe_unido.index=rango
dataframe_unido
# Out:
#           Cédula       Nombre   Apellido  \
# 1     1102792827       Samuel  Nicholson
# 2     1102792828      Jessica    Huffman
# 3     1102792829      Beverly    Johnson
# 4     1102792830     Kimberly     Watson
# 5     1102792831        Linda     Tucker
# ...          ...          ...        ...
# 996   1102793822      Michael      Mcgee
# 997   1102793823  Christopher      Boyle
# 998   1102793824       Joseph    Griffin
# 999   1102793825      Michael   Williams
# 1000  1102793826    Alexander     Ortega
#
#                                               Dirección  \
# 1     266 Johnson Rest Apt. 564\nSouth Kristen, NM 8...
# 2                      PSC 9201, Box 4184\nAPO AA 81129
# 3     7732 Roberts Shores Suite 769\nLoganborough, M...
# 4     054 Rodriguez Points Apt. 308\nColechester, SC...
# 5       964 Lucas Key Suite 367\nSanchezville, VA 38199
# ...                                                 ...
# 996   313 Lowery Port Suite 141\nPort Johnland, CO 3...
# 997     051 Mercer Mews Apt. 085\nButlermouth, NY 59759
# 998    7827 Samantha Drives\nWest Amandamouth, OK 48139
# 999            2786 Patel Knolls\nValeriefort, HI 69657
# 1000  2044 Chambers Forge Suite 937\nPort Jonathanch...
#
#                Correo electrónico Fecha de nacimiento
# 1             oharris@example.org          1983-01-07
# 2            xhiggins@example.net          2023-10-31
# 3              jcurry@example.com          1935-10-31
# 4           boydmegan@example.org          1931-09-08
# 5     kaitlynphillips@example.net          1929-10-14
# ...                           ...                 ...
# 996    patriciaharmon@example.net          1941-08-05
# 997     christopher00@example.com          2008-11-01
# 998       edwardsleon@example.com          1996-11-18
# 999        jodymartin@example.com          2011-12-24
# 1000           paul21@example.org          1918-07-16
#
# [1000 rows x 6 columns]
